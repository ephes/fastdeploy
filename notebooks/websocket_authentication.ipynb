# %%
# %load_ext nb_black

# %%
from jose import JWTError, jwt

from fastapi import HTTPException, status

from datetime import timedelta

from app.config import settings
from app.auth import create_access_token, TokenData

# %%
access_token = create_access_token({"sub": "jochen"}, timedelta(seconds=5))
print(access_token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJqb2NoZW4iLCJleHAiOjE2MzQ5NzMwOTh9.vrVhmOlAlVIQtvsfyQk-wKd9PwRnuONAHq8v8SpRlRk

# %%
def verify_access_token(access_token: str):
    credentials_exception = HTTPException(
        status_code=status.HTTP_401_UNAUTHORIZED,
        detail="Could not validate credentials",
        headers={"WWW-Authenticate": "Bearer"},
    )
    try:
        payload = jwt.decode(
            access_token,
            settings.secret_key,
            algorithms=[settings.password_hash_algorithm],
        )
        username: str = payload.get("sub")
        if username is None:
            raise credentials_exception
        token_data = TokenData(username=username)
    except JWTError:
        raise credentials_exception
    return token_data

# %%
payload = jwt.decode(
    access_token, settings.secret_key, algorithms=[settings.password_hash_algorithm]
)
username = payload.get("sub")
print(username)
# Out:
# ---------------------------------------------------------------------------
# ExpiredSignatureError                     Traceback (most recent call last)
# /var/folders/35/mhty_0hd42ddfvyk3_09f1hc0000gn/T/ipykernel_48097/2248285744.py in <module>
# ----> 1 payload = jwt.decode(
#       2     access_token, settings.secret_key, algorithms=[settings.password_hash_algorithm]
#       3 )
#       4 username = payload.get("sub")
#       5 print(username)
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/jose/jwt.py in decode(token, key, algorithms, options, audience, issuer, subject, access_token)
#     155         raise JWTError("Invalid payload string: must be a json object")
#     156
# --> 157     _validate_claims(
#     158         claims,
#     159         audience=audience,
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/jose/jwt.py in _validate_claims(claims, audience, issuer, subject, algorithm, access_token, options)
#     479
#     480     if options.get("verify_exp"):
# --> 481         _validate_exp(claims, leeway=leeway)
#     482
#     483     if options.get("verify_aud"):
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/jose/jwt.py in _validate_exp(claims, leeway)
#     312
#     313     if exp < (now - leeway):
# --> 314         raise ExpiredSignatureError("Signature has expired.")
#     315
#     316
#
# ExpiredSignatureError: Signature has expired.

# %%
verify_access_token(access_token)
# Out:
# ---------------------------------------------------------------------------
# ExpiredSignatureError                     Traceback (most recent call last)
# /var/folders/35/mhty_0hd42ddfvyk3_09f1hc0000gn/T/ipykernel_48097/811894313.py in verify_access_token(access_token)
#       7     try:
# ----> 8         payload = jwt.decode(
#       9             access_token,
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/jose/jwt.py in decode(token, key, algorithms, options, audience, issuer, subject, access_token)
#     156
# --> 157     _validate_claims(
#     158         claims,
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/jose/jwt.py in _validate_claims(claims, audience, issuer, subject, algorithm, access_token, options)
#     480     if options.get("verify_exp"):
# --> 481         _validate_exp(claims, leeway=leeway)
#     482
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/jose/jwt.py in _validate_exp(claims, leeway)
#     313     if exp < (now - leeway):
# --> 314         raise ExpiredSignatureError("Signature has expired.")
#     315
#
# ExpiredSignatureError: Signature has expired.
#
# During handling of the above exception, another exception occurred:
#
# HTTPException                             Traceback (most recent call last)
# /var/folders/35/mhty_0hd42ddfvyk3_09f1hc0000gn/T/ipykernel_48097/250410587.py in <module>
# ----> 1 verify_access_token(access_token)
#
# /var/folders/35/mhty_0hd42ddfvyk3_09f1hc0000gn/T/ipykernel_48097/811894313.py in verify_access_token(access_token)
#      16         token_data = TokenData(username=username)
#      17     except JWTError:
# ---> 18         raise credentials_exception
#      19     return token_data
#
# HTTPException:

# %%
from uuid import uuid4

# %%
uuid4()
# Out:
# UUID('0e0fc30d-ae80-401d-aed9-7e77e4e50123')
