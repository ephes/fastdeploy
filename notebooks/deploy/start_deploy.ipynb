# %%
from deploy.domain import model
from deploy.bootstrap import bootstrap
from deploy.tasks import get_deploy_environment, run_deploy

# %%
import subprocess

# %%
subprocess.Popen(["/bin/sleep", "10"], start_new_session=True, env={})
# Out:
# <Popen: returncode: None args: ['/bin/sleep', '10']>
