# %%
# %load_ext nb_black

# %%
import json

from sqlmodel import Session, select

from app.models import Service
from app import database

# %%
service_from_request = Service(name="fastdeploy")

# %%
with Session(database.engine) as session:
    service = session.exec(
        select(Service).where(Service.name == service_from_request.name)
    ).first()

# %%
print(service)
# Out:
# id=1 name='fastdeploy'

# %%
json.loads('{"service":"fastdeploy","origin":"GitHub"}')
# Out:
# {'service': 'fastdeploy', 'origin': 'GitHub'}

# %%
service = Service(name="fastdeploy")
with Session(database.engine) as session:
    session.add(service)
    session.commit()

# %%
foo = """
{"position": 12, "start": "2021-10-30T06:40:13.962161", "end": "2021-10-30T06:40:14.643597", "name": "Create a symbolic link for traefik loadbalancer", "changed": false, "state": "link", "misc": {"dest": "/etc/traefik/dynamic/deploy.traefik.yml", "src": "/home/deploy/site/ansible/deploy.traefik.yml", "changed": false, "diff": {"before": {"path": "/etc/traefik/dynamic/deploy.traefik.yml"}, "after": {"path": "/etc/traefik/dynamic/deploy.traefik.yml"}}, "uid": 0, "gid": 0, "owner": "root", "group": "root", "mode": "0777", "state": "link", "size": 44, "invocation": {"module_args": {"src": "/home/deploy/site/ansible/deploy.traefik.yml", "dest": "/etc/traefik/dynamic/deploy.traefik.yml", "state": "link", "path": "/etc/traefik/dynamic/deploy.traefik.yml", "recurse": false, "force": false, "follow": true, "modification_time_format": "%Y%m%d%H%M.%S", "access_time_format": "%Y%m%d%H%M.%S", "unsafe_writes": false, "_original_basename": null, "_diff_peek": null, "modification_time": null, "access_time": null, "mode": null, "owner": null, "group": null, "seuser": null, "serole": null, "selevel": null, "setype": null, "attributes": null}}, "_ansible_no_log": false}}
"""

# %%
step = json.loads(foo)

# %%
with Session(database.engine) as session:
    for service in session.exec(select(Service)).all():
        print(service)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# OperationalError: no such column: service.collect
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/dg/20nm141d3hj2hv67hjl6zmkc0000gn/T/ipykernel_18227/2821241848.py in <module>
#       1 with Session(database.engine) as session:
# ----> 2     for service in session.exec(select(Service)).all():
#       3         print(service)
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlmodel/orm/session.py in exec(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#      58         **kw: Any,
#      59     ) -> Union[Result[_TSelectParam], ScalarResult[_TSelectParam]]:
# ---> 60         results = super().execute(
#      61             statement,
#      62             params=params,
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/orm/session.py in execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#    1687         else:
#    1688             conn = self._connection_for_bind(bind)
# -> 1689         result = conn._execute_20(statement, params or {}, execution_options)
#    1690
#    1691         if compile_state_cls:
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _execute_20(self, statement, parameters, execution_options)
#    1609             )
#    1610         else:
# -> 1611             return meth(self, args_10style, kwargs_10style, execution_options)
#    1612
#    1613     def exec_driver_sql(
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1476             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1477         )
# -> 1478         ret = self._execute_context(
#    1479             dialect,
#    1480             dialect.execution_ctx_cls._init_compiled,
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840
#    1841         except BaseException as e:
# -> 1842             self._handle_dbapi_exception(
#    1843                 e, statement, parameters, cursor, context
#    1844             )
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2021                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2022             elif should_wrap:
# -> 2023                 util.raise_(
#    2024                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2025                 )
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                             break
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#    1801                     )
#
# ~/.virtualenvs/fd/lib/python3.10/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such column: service.collect
# [SQL: SELECT service.name, service.id, service.collect, service.deploy
# FROM service]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
